# %% [markdown]
# # Network Dynamics: Node Centrality - Lab
#
# ## Introduction
#
# In this lab, you'll get a chance to practice implementing and interpreting the centrality metrics from the previous section. You'll do this be investigating the social network from Game of Thrones!
#
# ## Objectives
# You will be able to:
# - Understand and explain network centrality and its importance in graph analysis
# - Understand and calculate Degree, Closeness, Betweenness and Eigenvector centrality measures
# - Describe the use case for several centrality measures

# %% [markdown]
# ## Character Interaction Graph Data
#
# A. J. Beveridge, and J. Shan  created a network from George R. Martin's "A song of ice and fire" by extracting relationships between characters of the story. [The dataset is available at Github](https://github.com/mathbeveridge/asoiaf). Relationships between characters were formed every time a character's name appears within 15 words of another character. This was designed as an approximate metric for character's interactions with each other. The results of this simple analysis are quite profound and produce interesting visuals such as this graph:
#
# <img src="images/got.png" width=800>
#
# With that, it's your turn to start investigating the most central characters!

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ##  Load the dataset
#
# Start by loading the dataset as a pandas DataFrame. From this, you'll then create a network representation of the dataset using NetworkX.
#
# The dataset is stored in the file `asoiaf-all-edges.csv`.

# %%
# Load edges into dataframes
edges = pd.read_csv('asoiaf-all-edges.csv')
edges.head()
# Out:
#            Source            Target        Type  id  weight
# 0  Addam-Marbrand     Brynden-Tully  Undirected   0       3
# 1  Addam-Marbrand  Cersei-Lannister  Undirected   1       3
# 2  Addam-Marbrand       Gyles-Rosby  Undirected   2       3
# 3  Addam-Marbrand   Jaime-Lannister  Undirected   3      14
# 4  Addam-Marbrand      Jalabhar-Xho  Undirected   4       3

# %% [markdown]
# ## Create Empty graph instances for each book

# %%
# Create empty instances for each book above
G = nx.Graph()

# %% [markdown]
# ## Create a Graph
#
# Now that you have the data loaded as a pandas DataFrame, iterate through the data and create appropriate edges to the empty graph you instantiated above. Be sure to add the weight to each edge.

# %%
# Read edge lists into dataframes
for edge in edges.iterrows():
    G.add_edge(edge[1]['Source'], edge[1]['Target'], weight=edge[1]['weight'])

# %% [markdown]
# ## Calculate Degree
#
# To start the investigation of the most central characters in the books, calculate the degree centrality for each character. Then create a bar graph of the top 10 characters according to degree centrality.

# %%
degrees = nx.degree(G)
deg_top_10 = pd.DataFrame(sorted(degrees, key=lambda x: x[1], reverse=True)[:10], columns=['character', 'degree'])
sns.barplot(x='character', y='degree', data=deg_top_10);

# %% [markdown]
# ## Closeness Centrality
#
# Repeat the above exercise for the top 10 characters according to closeness centrality.

# %%
closenesses = nx.closeness_centrality(G)
#top_10 = pd.DataFrame(sorted(closenesses, key=lambda x: x[1], reverse=True)[:10], columns=['character', 'closeness'])
# sns.barplot(x='character', y='closeness', data=top_10);
# Out:
# dict

# %%
clo_top_10 = pd.DataFrame(sorted(closenesses.items(), key=lambda x: x[1], reverse=True)[:10], columns=['character', 'closeness'])
sns.barplot(x='character', y='closeness', data=clo_top_10);

# %% [markdown]
# ## Betweeness Centrality
#
# Repeat the process one more time for betweeness centrality.

# %%
betweenness = nx.betweenness_centrality(G)

# %%
sorted_betweenness = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)[:10]
bet_top_10 = pd.DataFrame(sorted_betweenness, columns=['character', 'betweenness'])
sns.barplot(x='character', y='betweenness', data=bet_top_10);

# %% [markdown]
# ## Putting it All Together
#
# Great! Now try putting all of these metrics together along with eigenvector centrality. Combine all four metrics into a single dataframe for each character.

# %%
degrees = nx.degree_centrality(G)
closeness = nx.closeness_centrality(G)
betweeness = nx.betweenness_centrality(G)
eigs = nx.eigenvector_centrality(G)
df = pd.DataFrame([degrees, closeness, betweeness, eigs]).transpose()
df.columns = ["degrees", "closeness", "betweeness", "eigs"]
df.head()
# Out:
#                                    degrees  closeness  betweeness      eigs
# Addam-Marbrand                    0.015094   0.345803    0.000470  0.052658
# Aegon-Frey-(son-of-Stevron)       0.005031   0.313609    0.000000  0.014688
# Aegon-I-Targaryen                 0.011321   0.361692    0.006891  0.025584
# Aegon-Targaryen-(son-of-Rhaegar)  0.018868   0.342230    0.006012  0.024691
# Aegon-V-Targaryen                 0.001258   0.262636    0.000000  0.001226

# %% [markdown]
# ## Identifying Key Players
#
# While centrality can tell us a lot, you've also begun to see how certain individuals may not be the most central characters, but can be pivotal in the flow of information from one community to another. In the previous lesson, such nodes were labeled as 'bridges' acting as the intermediaries between two clusters. Try and identify such characters from this dataset.

# %%
#Your code here
sorted(df.iterrows(), key=lambda x: x[1].closeness, reverse=True)
# Out:
# [('Tyrion-Lannister', degrees       0.153459
#   closeness     0.476333
#   betweeness    0.162191
#   eigs          0.251558
#   Name: Tyrion-Lannister, dtype: float64),
#  ('Robert-Baratheon', degrees       0.081761
#   closeness     0.459272
#   betweeness    0.078228
#   eigs          0.194375
#   Name: Robert-Baratheon, dtype: float64),
#  ('Eddard-Stark', degrees       0.093082
#   closeness     0.455849
#   betweeness    0.078732
#   eigs          0.191660
#   Name: Eddard-Stark, dtype: float64),
#  ('Cersei-Lannister', degrees       0.122013
#   closeness     0.454545
#   betweeness    0.088704
#   eigs          0.235771
#   Name: Cersei-Lannister, dtype: float64),
#  ('Jaime-Lannister', degrees       0.127044
#   closeness     0.451961
#   betweeness    0.100838
#   eigs          0.226339
#   Name: Jaime-Lannister, dtype: float64),
#  ('Jon-Snow', degrees       0.143396
#   closeness     0.445378
#   betweeness    0.192120
#   eigs          0.144211
#   Name: Jon-Snow, dtype: float64),
#  ('Stannis-Baratheon', degrees       0.111950
#   closeness     0.444631
#   betweeness    0.110140
#   eigs          0.182085
#   Name: Stannis-Baratheon, dtype: float64),
#  ('Robb-Stark', degrees       0.093082
#   closeness     0.444134
#   betweeness    0.066468
#   eigs          0.173196
#   Name: Robb-Stark, dtype: float64),
#  ('Joffrey-Baratheon', degrees       0.086792
#   closeness     0.433952
#   betweeness    0.031759
#   eigs          0.214376
#   Name: Joffrey-Baratheon, dtype: float64),
#  ('Catelyn-Stark', degrees       0.094340
#   closeness     0.433479
#   betweeness    0.054974
#   eigs          0.175886
#   Name: Catelyn-Stark, dtype: float64),
#  ('Sansa-Stark', degrees       0.094340
#   closeness     0.433007
#   betweeness    0.048691
#   eigs          0.205842
#   Name: Sansa-Stark, dtype: float64),
#  ('Arya-Stark', degrees       0.105660
#   closeness     0.431362
#   betweeness    0.087242
#   eigs          0.172624
#   Name: Arya-Stark, dtype: float64),
#  ('Theon-Greyjoy', degrees       0.083019
#   closeness     0.423323
#   betweeness    0.111283
#   eigs          0.102481
#   Name: Theon-Greyjoy, dtype: float64),
#  ('Bran-Stark', degrees       0.067925
#   closeness     0.418862
#   betweeness    0.044911
#   eigs          0.122544
#   Name: Bran-Stark, dtype: float64),
#  ('Tywin-Lannister', degrees       0.060377
#   closeness     0.411278
#   betweeness    0.020670
#   eigs          0.159778
#   Name: Tywin-Lannister, dtype: float64),
#  ('Rodrik-Cassel', degrees       0.037736
#   closeness     0.403144
#   betweeness    0.011062
#   eigs          0.093609
#   Name: Rodrik-Cassel, dtype: float64),
#  ('Petyr-Baelish', degrees       0.059119
#   closeness     0.402124
#   betweeness    0.025899
#   eigs          0.152960
#   Name: Petyr-Baelish, dtype: float64),
#  ('Jory-Cassel', degrees       0.026415
#   closeness     0.401515
#   betweeness    0.004878
#   eigs          0.084119
#   Name: Jory-Cassel, dtype: float64),
#  ('Varys', degrees       0.042767
#   closeness     0.401515
#   betweeness    0.009201
#   eigs          0.129805
#   Name: Varys, dtype: float64),
#  ('Renly-Baratheon', degrees       0.047799
#   closeness     0.398097
#   betweeness    0.018923
#   eigs          0.130551
#   Name: Renly-Baratheon, dtype: float64),
#  ('Roose-Bolton', degrees       0.035220
#   closeness     0.392012
#   betweeness    0.005556
#   eigs          0.090200
#   Name: Roose-Bolton, dtype: float64),
#  ('Rickon-Stark', degrees       0.021384
#   closeness     0.391240
#   betweeness    0.001981
#   eigs          0.063343
#   Name: Rickon-Stark, dtype: float64),
#  ('Benjen-Stark', degrees       0.017610
#   closeness     0.389706
#   betweeness    0.005675
#   eigs          0.056313
#   Name: Benjen-Stark, dtype: float64),
#  ('Barristan-Selmy', degrees       0.051572
#   closeness     0.386861
#   betweeness    0.045550
#   eigs          0.098091
#   Name: Barristan-Selmy, dtype: float64),
#  ('Tommen-Baratheon', degrees       0.041509
#   closeness     0.384615
#   betweeness    0.006251
#   eigs          0.117158
#   Name: Tommen-Baratheon, dtype: float64),
#  ('Brienne-of-Tarth', degrees       0.056604
#   closeness     0.384429
#   betweeness    0.032252
#   eigs          0.116305
#   Name: Brienne-of-Tarth, dtype: float64),
#  ('Daenerys-Targaryen', degrees       0.091824
#   closeness     0.383317
#   betweeness    0.118418
#   eigs          0.063043
#   Name: Daenerys-Targaryen, dtype: float64),
#  ('Luwin', degrees       0.027673
#   closeness     0.383133
#   betweeness    0.003151
#   eigs          0.059696
#   Name: Luwin, dtype: float64),
#  ('Jon-Arryn', degrees       0.021384
#   closeness     0.382764
#   betweeness    0.008812
#   eigs          0.079628
#   Name: Jon-Arryn, dtype: float64),
#  ('Sandor-Clegane', degrees       0.045283
#   closeness     0.382212
#   betweeness    0.008828
#   eigs          0.122847
#   Name: Sandor-Clegane, dtype: float64),
#  ('Loras-Tyrell', degrees       0.035220
#   closeness     0.382028
#   betweeness    0.001443
#   eigs          0.121092
#   Name: Loras-Tyrell, dtype: float64),
#  ('Mace-Tyrell', degrees       0.028931
#   closeness     0.382028
#   betweeness    0.005881
#   eigs          0.087405
#   Name: Mace-Tyrell, dtype: float64),
#  ('Janos-Slynt', degrees       0.028931
#   closeness     0.381844
#   betweeness    0.007183
#   eigs          0.081748
#   Name: Janos-Slynt, dtype: float64),
#  ('Pycelle', degrees       0.033962
#   closeness     0.380383
#   betweeness    0.007406
#   eigs          0.111320
#   Name: Pycelle, dtype: float64),
#  ('Gregor-Clegane', degrees       0.041509
#   closeness     0.379838
#   betweeness    0.005486
#   eigs          0.122875
#   Name: Gregor-Clegane, dtype: float64),
#  ('Lysa-Arryn', degrees       0.030189
#   closeness     0.377493
#   betweeness    0.006065
#   eigs          0.088361
#   Name: Lysa-Arryn, dtype: float64),
#  ('Myrcella-Baratheon', degrees       0.027673
#   closeness     0.377135
#   betweeness    0.020193
#   eigs          0.075358
#   Name: Myrcella-Baratheon, dtype: float64),
#  ('Brynden-Tully', degrees       0.023899
#   closeness     0.371495
#   betweeness    0.002227
#   eigs          0.060019
#   Name: Brynden-Tully, dtype: float64),
#  ('Jeor-Mormont', degrees       0.035220
#   closeness     0.371322
#   betweeness    0.017268
#   eigs          0.042296
#   Name: Jeor-Mormont, dtype: float64),
#  ('Yoren', degrees       0.022642
#   closeness     0.370975
#   betweeness    0.004849
#   eigs          0.048584
#   Name: Yoren, dtype: float64),
#  ('Mordane', degrees       0.013836
#   closeness     0.370457
#   betweeness    0.000477
#   eigs          0.059861
#   Name: Mordane, dtype: float64),
#  ('Mance-Rayder', degrees       0.041509
#   closeness     0.369940
#   betweeness    0.013605
#   eigs          0.050963
#   Name: Mance-Rayder, dtype: float64),
#  ('Meryn-Trant', degrees       0.026415
#   closeness     0.368226
#   betweeness    0.000941
#   eigs          0.086168
#   Name: Meryn-Trant, dtype: float64),
#  ('Rhaegar-Targaryen', degrees       0.022642
#   closeness     0.368056
#   betweeness    0.007842
#   eigs          0.057458
#   Name: Rhaegar-Targaryen, dtype: float64),
#  ('Aerys-II-Targaryen', degrees       0.023899
#   closeness     0.366359
#   betweeness    0.014069
#   eigs          0.067479
#   Name: Aerys-II-Targaryen, dtype: float64),
#  ('Ramsay-Snow', degrees       0.028931
#   closeness     0.366359
#   betweeness    0.016713
#   eigs          0.047208
#   Name: Ramsay-Snow, dtype: float64),
#  ('Ilyn-Payne', degrees       0.027673
#   closeness     0.365685
#   betweeness    0.000895
#   eigs          0.094924
#   Name: Ilyn-Payne, dtype: float64),
#  ('Balon-Greyjoy', degrees       0.016352
#   closeness     0.364679
#   betweeness    0.009546
#   eigs          0.043304
#   Name: Balon-Greyjoy, dtype: float64),
#  ('Alliser-Thorne', degrees       0.018868
#   closeness     0.363014
#   betweeness    0.002218
#   eigs          0.039766
#   Name: Alliser-Thorne, dtype: float64),
#  ('Kevan-Lannister', degrees       0.021384
#   closeness     0.362682
#   betweeness    0.001893
#   eigs          0.073661
#   Name: Kevan-Lannister, dtype: float64),
#  ('Bronn', degrees       0.031447
#   closeness     0.362352
#   betweeness    0.002900
#   eigs          0.074281
#   Name: Bronn, dtype: float64),
#  ('Margaery-Tyrell', degrees       0.037736
#   closeness     0.362352
#   betweeness    0.004546
#   eigs          0.091878
#   Name: Margaery-Tyrell, dtype: float64),
#  ('Aegon-I-Targaryen', degrees       0.011321
#   closeness     0.361692
#   betweeness    0.006891
#   eigs          0.025584
#   Name: Aegon-I-Targaryen, dtype: float64),
#  ('Doran-Martell', degrees       0.026415
#   closeness     0.360217
#   betweeness    0.014537
#   eigs          0.052173
#   Name: Doran-Martell, dtype: float64),
#  ('Walder-Frey', degrees       0.023899
#   closeness     0.360054
#   betweeness    0.006634
#   eigs          0.054950
#   Name: Walder-Frey, dtype: float64),
#  ('Beric-Dondarrion', degrees       0.022642
#   closeness     0.358916
#   betweeness    0.002140
#   eigs          0.067161
#   Name: Beric-Dondarrion, dtype: float64),
#  ('Cleos-Frey', degrees       0.008805
#   closeness     0.357947
#   betweeness    0.000020
#   eigs          0.047965
#   Name: Cleos-Frey, dtype: float64),
#  ('Aemon-Targaryen-(Maester-Aemon)', degrees       0.032704
#   closeness     0.356023
#   betweeness    0.019000
#   eigs          0.035037
#   Name: Aemon-Targaryen-(Maester-Aemon), dtype: float64),
#  ('Oberyn-Martell', degrees       0.025157
#   closeness     0.356023
#   betweeness    0.009803
#   eigs          0.065783
#   Name: Oberyn-Martell, dtype: float64),
#  ('Wyman-Manderly', degrees       0.021384
#   closeness     0.355705
#   betweeness    0.009243
#   eigs          0.039026
#   Name: Wyman-Manderly, dtype: float64),
#  ('Melisandre', degrees       0.028931
#   closeness     0.355387
#   betweeness    0.006490
#   eigs          0.041724
#   Name: Melisandre, dtype: float64),
#  ('Jorah-Mormont', degrees       0.032704
#   closeness     0.355228
#   betweeness    0.010827
#   eigs          0.031713
#   Name: Jorah-Mormont, dtype: float64),
#  ('Qyburn', degrees       0.022642
#   closeness     0.353490
#   betweeness    0.001701
#   eigs          0.056992
#   Name: Qyburn, dtype: float64),
#  ('Davos-Seaworth', degrees       0.041509
#   closeness     0.352706
#   betweeness    0.023847
#   eigs          0.043802
#   Name: Davos-Seaworth, dtype: float64),
#  ('Lancel-Lannister', degrees       0.015094
#   closeness     0.352706
#   betweeness    0.000520
#   eigs          0.058368
#   Name: Lancel-Lannister, dtype: float64),
#  ('Samwell-Tarly', degrees       0.055346
#   closeness     0.352706
#   betweeness    0.041466
#   eigs          0.044536
#   Name: Samwell-Tarly, dtype: float64),
#  ('Dontos-Hollard', degrees       0.011321
#   closeness     0.352237
#   betweeness    0.000468
#   eigs          0.041663
#   Name: Dontos-Hollard, dtype: float64),
#  ('Asha-Greyjoy', degrees       0.031447
#   closeness     0.351770
#   betweeness    0.033025
#   eigs          0.023000
#   Name: Asha-Greyjoy, dtype: float64),
#  ('Boros-Blount', degrees       0.017610
#   closeness     0.351459
#   betweeness    0.000228
#   eigs          0.063081
#   Name: Boros-Blount, dtype: float64),
#  ('Edmure-Tully', degrees       0.030189
#   closeness     0.351304
#   betweeness    0.003461
#   eigs          0.065627
#   Name: Edmure-Tully, dtype: float64),
#  ('Shae', degrees       0.016352
#   closeness     0.350838
#   betweeness    0.000826
#   eigs          0.049230
#   Name: Shae, dtype: float64),
#  ('Jon-Connington', degrees       0.020126
#   closeness     0.350375
#   betweeness    0.012690
#   eigs          0.033734
#   Name: Jon-Connington, dtype: float64),
#  ('Viserys-Targaryen', degrees       0.017610
#   closeness     0.350375
#   betweeness    0.002457
#   eigs          0.030213
#   Name: Viserys-Targaryen, dtype: float64),
#  ('Jeyne-Poole', degrees       0.016352
#   closeness     0.348837
#   betweeness    0.001727
#   eigs          0.039347
#   Name: Jeyne-Poole, dtype: float64),
#  ('Balon-Swann', degrees       0.020126
#   closeness     0.348684
#   betweeness    0.003599
#   eigs          0.056623
#   Name: Balon-Swann, dtype: float64),
#  ('Amory-Lorch', degrees       0.025157
#   closeness     0.348226
#   betweeness    0.001181
#   eigs          0.069038
#   Name: Amory-Lorch, dtype: float64),
#  ('Osmund-Kettleblack', degrees       0.022642
#   closeness     0.347921
#   betweeness    0.000671
#   eigs          0.068849
#   Name: Osmund-Kettleblack, dtype: float64),
#  ('Randyll-Tarly', degrees       0.016352
#   closeness     0.347921
#   betweeness    0.004473
#   eigs          0.031258
#   Name: Randyll-Tarly, dtype: float64),
#  ('Val', degrees       0.011321
#   closeness     0.347465
#   betweeness    0.000812
#   eigs          0.023282
#   Name: Val, dtype: float64),
#  ('Taena-of-Myr', degrees       0.015094
#   closeness     0.347313
#   betweeness    0.000492
#   eigs          0.044600
#   Name: Taena-of-Myr, dtype: float64),
#  ('Mandon-Moore', degrees       0.011321
#   closeness     0.347162
#   betweeness    0.000023
#   eigs          0.053099
#   Name: Mandon-Moore, dtype: float64),
#  ('Illyrio-Mopatis', degrees       0.015094
#   closeness     0.346556
#   betweeness    0.001203
#   eigs          0.023548
#   Name: Illyrio-Mopatis, dtype: float64),
#  ('Rickard-Karstark', degrees       0.015094
#   closeness     0.346556
#   betweeness    0.000916
#   eigs          0.041517
#   Name: Rickard-Karstark, dtype: float64),
#  ('Nan', degrees       0.010063
#   closeness     0.346254
#   betweeness    0.000714
#   eigs          0.025466
#   Name: Nan, dtype: float64),
#  ('Addam-Marbrand', degrees       0.015094
#   closeness     0.345803
#   betweeness    0.000470
#   eigs          0.052658
#   Name: Addam-Marbrand, dtype: float64),
#  ('Harys-Swyft', degrees       0.011321
#   closeness     0.345803
#   betweeness    0.000083
#   eigs          0.036590
#   Name: Harys-Swyft, dtype: float64),
#  ('Galbart-Glover', degrees       0.010063
#   closeness     0.345202
#   betweeness    0.000946
#   eigs          0.027741
#   Name: Galbart-Glover, dtype: float64),
#  ('Olenna-Redwyne', degrees       0.011321
#   closeness     0.345052
#   betweeness    0.000293
#   eigs          0.050502
#   Name: Olenna-Redwyne, dtype: float64),
#  ('Cortnay-Penrose', degrees       0.008805
#   closeness     0.344156
#   betweeness    0.000660
#   eigs          0.026769
#   Name: Cortnay-Penrose, dtype: float64),
#  ('Hoster-Tully', degrees       0.012579
#   closeness     0.344007
#   betweeness    0.000348
#   eigs          0.036161
#   Name: Hoster-Tully, dtype: float64),
#  ('Elia-Martell', degrees       0.011321
#   closeness     0.343116
#   betweeness    0.002700
#   eigs          0.040089
#   Name: Elia-Martell, dtype: float64),
#  ('Aegon-Targaryen-(son-of-Rhaegar)', degrees       0.018868
#   closeness     0.342230
#   betweeness    0.006012
#   eigs          0.024691
#   Name: Aegon-Targaryen-(son-of-Rhaegar), dtype: float64),
#  ('Gerold-Hightower', degrees       0.010063
#   closeness     0.342230
#   betweeness    0.008396
#   eigs          0.027488
#   Name: Gerold-Hightower, dtype: float64),
#  ('Selyse-Florent', degrees       0.023899
#   closeness     0.342230
#   betweeness    0.005671
#   eigs          0.028015
#   Name: Selyse-Florent, dtype: float64),
#  ('Vayon-Poole', degrees       0.006289
#   closeness     0.342083
#   betweeness    0.000000
#   eigs          0.030743
#   Name: Vayon-Poole, dtype: float64),
#  ('Shireen-Baratheon', degrees       0.016352
#   closeness     0.341935
#   betweeness    0.003259
#   eigs          0.029089
#   Name: Shireen-Baratheon, dtype: float64),
#  ('Gendry', degrees       0.025157
#   closeness     0.341788
#   betweeness    0.012467
#   eigs          0.040038
#   Name: Gendry, dtype: float64),
#  ('Elmar-Frey', degrees       0.011321
#   closeness     0.341495
#   betweeness    0.000105
#   eigs          0.043213
#   Name: Elmar-Frey, dtype: float64),
#  ('Moqorro', degrees       0.006289
#   closeness     0.341202
#   betweeness    0.002410
#   eigs          0.011781
#   Name: Moqorro, dtype: float64),
#  ('Orton-Merryweather', degrees       0.012579
#   closeness     0.341202
#   betweeness    0.000081
#   eigs          0.037216
#   Name: Orton-Merryweather, dtype: float64),
#  ('Robert-Arryn', degrees       0.025157
#   closeness     0.340909
#   betweeness    0.011219
#   eigs          0.041725
#   Name: Robert-Arryn, dtype: float64),
#  ('Thoros-of-Myr', degrees       0.011321
#   closeness     0.340180
#   betweeness    0.000503
#   eigs          0.030449
#   Name: Thoros-of-Myr, dtype: float64),
#  ('Rafford', degrees       0.016352
#   closeness     0.340034
#   betweeness    0.000047
#   eigs          0.053850
#   Name: Rafford, dtype: float64),
#  ('Gyles-Rosby', degrees       0.022642
#   closeness     0.339453
#   betweeness    0.000415
#   eigs          0.059528
#   Name: Gyles-Rosby, dtype: float64),
#  ('Marillion', degrees       0.011321
#   closeness     0.339453
#   betweeness    0.000084
#   eigs          0.038731
#   Name: Marillion, dtype: float64),
#  ('Owen', degrees       0.012579
#   closeness     0.339309
#   betweeness    0.000805
#   eigs          0.015821
#   Name: Owen, dtype: float64),
#  ('Paxter-Redwyne', degrees       0.007547
#   closeness     0.338875
#   betweeness    0.000773
#   eigs          0.022910
#   Name: Paxter-Redwyne, dtype: float64),
#  ('Ben-Plumm', degrees       0.011321
#   closeness     0.338298
#   betweeness    0.001077
#   eigs          0.016716
#   Name: Ben-Plumm, dtype: float64),
#  ('Jacelyn-Bywater', degrees       0.011321
#   closeness     0.338298
#   betweeness    0.000015
#   eigs          0.042782
#   Name: Jacelyn-Bywater, dtype: float64),
#  ('Brandon-Stark', degrees       0.010063
#   closeness     0.338154
#   betweeness    0.000462
#   eigs          0.030520
#   Name: Brandon-Stark, dtype: float64),
#  ('Cressen', degrees       0.011321
#   closeness     0.337723
#   betweeness    0.000353
#   eigs          0.023440
#   Name: Cressen, dtype: float64),
#  ('Aurane-Waters', degrees       0.011321
#   closeness     0.337436
#   betweeness    0.000078
#   eigs          0.031641
#   Name: Aurane-Waters, dtype: float64),
#  ('Polliver', degrees       0.017610
#   closeness     0.337150
#   betweeness    0.000090
#   eigs          0.053893
#   Name: Polliver, dtype: float64),
#  ('Bowen-Marsh', degrees       0.022642
#   closeness     0.336864
#   betweeness    0.001066
#   eigs          0.026342
#   Name: Bowen-Marsh, dtype: float64),
#  ('Podrick-Payne', degrees       0.013836
#   closeness     0.336864
#   betweeness    0.003391
#   eigs          0.035715
#   Name: Podrick-Payne, dtype: float64),
#  ('Marq-Piper', degrees       0.010063
#   closeness     0.336722
#   betweeness    0.000178
#   eigs          0.032353
#   Name: Marq-Piper, dtype: float64),
#  ('Osney-Kettleblack', degrees       0.013836
#   closeness     0.336722
#   betweeness    0.000488
#   eigs          0.030303
#   Name: Osney-Kettleblack, dtype: float64),
#  ('Tysha', degrees       0.005031
#   closeness     0.336437
#   betweeness    0.000015
#   eigs          0.025648
#   Name: Tysha, dtype: float64),
#  ('Garlan-Tyrell', degrees       0.008805
#   closeness     0.336010
#   betweeness    0.002519
#   eigs          0.037354
#   Name: Garlan-Tyrell, dtype: float64),
#  ('Penny', degrees       0.008805
#   closeness     0.336010
#   betweeness    0.000279
#   eigs          0.013779
#   Name: Penny, dtype: float64),
#  ('Benerro', degrees       0.005031
#   closeness     0.335726
#   betweeness    0.000037
#   eigs          0.011925
#   Name: Benerro, dtype: float64),
#  ('Jon-Umber-(Greatjon)', degrees       0.017610
#   closeness     0.335726
#   betweeness    0.001361
#   eigs          0.034922
#   Name: Jon-Umber-(Greatjon), dtype: float64),
#  ('Qavo-Nogarys', degrees       0.003774
#   closeness     0.335443
#   betweeness    0.000029
#   eigs          0.011513
#   Name: Qavo-Nogarys, dtype: float64),
#  ('High-Septon-(fat_one)', degrees       0.003774
#   closeness     0.334737
#   betweeness    0.000000
#   eigs          0.023011
#   Name: High-Septon-(fat_one), dtype: float64),
#  ('Mathis-Rowan', degrees       0.010063
#   closeness     0.334737
#   betweeness    0.002588
#   eigs          0.025172
#   Name: Mathis-Rowan, dtype: float64),
#  ('Devan-Seaworth', degrees       0.007547
#   closeness     0.334596
#   betweeness    0.000328
#   eigs          0.019365
#   Name: Devan-Seaworth, dtype: float64),
#  ('Ellaria-Sand', degrees       0.007547
#   closeness     0.334174
#   betweeness    0.000989
#   eigs          0.022006
#   Name: Ellaria-Sand, dtype: float64),
#  ('Mycah', degrees       0.006289
#   closeness     0.334174
#   betweeness    0.000000
#   eigs          0.031751
#   Name: Mycah, dtype: float64),
#  ('Edric-Storm', degrees       0.007547
#   closeness     0.334034
#   betweeness    0.001611
#   eigs          0.016183
#   Name: Edric-Storm, dtype: float64),
#  ('Victarion-Greyjoy', degrees       0.030189
#   closeness     0.333753
#   betweeness    0.036451
#   eigs          0.009395
#   Name: Victarion-Greyjoy, dtype: float64),
#  ('Willas-Tyrell', degrees       0.010063
#   closeness     0.333753
#   betweeness    0.000017
#   eigs          0.037531
#   Name: Willas-Tyrell, dtype: float64),
#  ('Lyanna-Stark', degrees       0.006289
#   closeness     0.333613
#   betweeness    0.000012
#   eigs          0.023790
#   Name: Lyanna-Stark, dtype: float64),
#  ('Pia', degrees       0.005031
#   closeness     0.333613
#   betweeness    0.000131
#   eigs          0.019018
#   Name: Pia, dtype: float64),
#  ('Tomard', degrees       0.008805
#   closeness     0.333473
#   betweeness    0.000146
#   eigs          0.029322
#   Name: Tomard, dtype: float64),
#  ('Willis-Wode', degrees       0.007547
#   closeness     0.333473
#   betweeness    0.000043
#   eigs          0.022615
#   Name: Willis-Wode, dtype: float64),
#  ('Chiswyck', degrees       0.016352
#   closeness     0.333333
#   betweeness    0.000043
#   eigs          0.046933
#   Name: Chiswyck, dtype: float64),
#  ('Dunsen', degrees       0.016352
#   closeness     0.333333
#   betweeness    0.000043
#   eigs          0.046933
#   Name: Dunsen, dtype: float64),
#  ('Tickler', degrees       0.015094
#   closeness     0.333194
#   betweeness    0.000000
#   eigs          0.046198
#   Name: Tickler, dtype: float64),
#  ('Godry-Farring', degrees       0.008805
#   closeness     0.333054
#   betweeness    0.001010
#   eigs          0.016027
#   Name: Godry-Farring, dtype: float64),
#  ('High-Septon-(Tyrions)', degrees       0.005031
#   closeness     0.332915
#   betweeness    0.000000
#   eigs          0.028450
#   Name: High-Septon-(Tyrions), dtype: float64),
#  ('Donal-Noye', degrees       0.010063
#   closeness     0.332775
#   betweeness    0.000240
#   eigs          0.017520
#   Name: Donal-Noye, dtype: float64),
#  ('Tanda-Stokeworth', degrees       0.008805
#   closeness     0.332775
#   betweeness    0.000023
#   eigs          0.031012
#   Name: Tanda-Stokeworth, dtype: float64),
#  ('Baelor-I-Targaryen', degrees       0.003774
#   closeness     0.332219
#   betweeness    0.000000
#   eigs          0.024256
#   Name: Baelor-I-Targaryen, dtype: float64),
#  ('Tycho-Nestoris', degrees       0.003774
#   closeness     0.331942
#   betweeness    0.000534
#   eigs          0.012224
#   Name: Tycho-Nestoris, dtype: float64),
#  ('Drogo', degrees       0.026415
#   closeness     0.331665
#   betweeness    0.012391
#   eigs          0.014788
#   Name: Drogo, dtype: float64),
#  ('Cotter-Pyke', degrees       0.012579
#   closeness     0.331526
#   betweeness    0.000260
#   eigs          0.018284
#   Name: Cotter-Pyke, dtype: float64),
#  ('Stafford-Lannister', degrees       0.005031
#   closeness     0.331388
#   betweeness    0.000049
#   eigs          0.024424
#   Name: Stafford-Lannister, dtype: float64),
#  ('Vardis-Egen', degrees       0.007547
#   closeness     0.331388
#   betweeness    0.000179
#   eigs          0.021502
#   Name: Vardis-Egen, dtype: float64),
#  ('Vargo-Hoat', degrees       0.012579
#   closeness     0.331112
#   betweeness    0.000684
#   eigs          0.030831
#   Name: Vargo-Hoat, dtype: float64),
#  ('Clydas', degrees       0.008805
#   closeness     0.330699
#   betweeness    0.000222
#   eigs          0.015288
#   Name: Clydas, dtype: float64),
#  ('Ryman-Frey', degrees       0.015094
#   closeness     0.330012
#   betweeness    0.001021
#   eigs          0.030267
#   Name: Ryman-Frey, dtype: float64),
#  ('Sybell-Spicer', degrees       0.007547
#   closeness     0.330012
#   betweeness    0.002362
#   eigs          0.016993
#   Name: Sybell-Spicer, dtype: float64),
#  ('Axell-Florent', degrees       0.012579
#   closeness     0.329739
#   betweeness    0.001703
#   eigs          0.017473
#   Name: Axell-Florent, dtype: float64),
#  ('Alayaya', degrees       0.005031
#   closeness     0.329465
#   betweeness    0.002516
#   eigs          0.019676
#   Name: Alayaya, dtype: float64),
#  ('Preston-Greenfield', degrees       0.002516
#   closeness     0.329056
#   betweeness    0.000000
#   eigs          0.017053
#   Name: Preston-Greenfield, dtype: float64),
#  ('Vylarr', degrees       0.002516
#   closeness     0.329056
#   betweeness    0.000000
#   eigs          0.017053
#   Name: Vylarr, dtype: float64),
#  ('Dalla', degrees       0.007547
#   closeness     0.328106
#   betweeness    0.000035
#   eigs          0.015991
#   Name: Dalla, dtype: float64),
#  ('Harwin', degrees       0.013836
#   closeness     0.327970
#   betweeness    0.000358
#   eigs          0.026943
#   Name: Harwin, dtype: float64),
#  ('Allar-Deem', degrees       0.002516
#   closeness     0.327295
#   betweeness    0.000000
#   eigs          0.011664
#   Name: Allar-Deem, dtype: float64),
#  ('Hallyne', degrees       0.002516
#   closeness     0.327295
#   betweeness    0.000000
#   eigs          0.016304
#   Name: Hallyne, dtype: float64),
#  ('Alyn', degrees       0.006289
#   closeness     0.327026
#   betweeness    0.000023
#   eigs          0.018421
#   Name: Alyn, dtype: float64),
#  ('Sigorn', degrees       0.005031
#   closeness     0.326891
#   betweeness    0.000054
#   eigs          0.013123
#   Name: Sigorn, dtype: float64),
#  ('Wyl-(guard)', degrees       0.005031
#   closeness     0.326891
#   betweeness    0.000269
#   eigs          0.017695
#   Name: Wyl-(guard), dtype: float64),
#  ('Arys-Oakheart', degrees       0.011321
#   closeness     0.326757
#   betweeness    0.001771
#   eigs          0.028629
#   Name: Arys-Oakheart, dtype: float64),
#  ('Melara-Hetherspoon', degrees       0.005031
#   closeness     0.326757
#   betweeness    0.002587
#   eigs          0.016499
#   Name: Melara-Hetherspoon, dtype: float64),
#  ('Haldon', degrees       0.013836
#   closeness     0.326489
#   betweeness    0.000285
#   eigs          0.014404
#   Name: Haldon, dtype: float64),
#  ('Nurse', degrees       0.005031
#   closeness     0.326489
#   betweeness    0.000013
#   eigs          0.010756
#   Name: Nurse, dtype: float64),
#  ('Dareon', degrees       0.007547
#   closeness     0.326355
#   betweeness    0.003076
#   eigs          0.014403
#   Name: Dareon, dtype: float64),
#  ('Lem', degrees       0.018868
#   closeness     0.326355
#   betweeness    0.005933
#   eigs          0.026561
#   Name: Lem, dtype: float64),
#  ('Hyle-Hunt', degrees       0.008805
#   closeness     0.326221
#   betweeness    0.000286
#   eigs          0.024296
#   Name: Hyle-Hunt, dtype: float64),
#  ('Rolly-Duckfield', degrees       0.010063
#   closeness     0.326087
#   betweeness    0.000013
#   eigs          0.013465
#   Name: Rolly-Duckfield, dtype: float64),
#  ('Rorge', degrees       0.011321
#   closeness     0.326087
#   betweeness    0.000418
#   eigs          0.018820
#   Name: Rorge, dtype: float64),
#  ('Hallis-Mollen', degrees       0.007547
#   closeness     0.325953
#   betweeness    0.000118
#   eigs          0.022696
#   Name: Hallis-Mollen, dtype: float64),
#  ('Barbrey-Dustin', degrees       0.007547
#   closeness     0.325686
#   betweeness    0.000183
#   eigs          0.016289
#   Name: Barbrey-Dustin, dtype: float64),
#  ('Raymun-Darry', degrees       0.002516
#   closeness     0.325553
#   betweeness    0.000000
#   eigs          0.013509
#   Name: Raymun-Darry, dtype: float64),
#  ('Willam-Dustin', degrees       0.002516
#   closeness     0.325553
#   betweeness    0.000000
#   eigs          0.013509
#   Name: Willam-Dustin, dtype: float64),
#  ('Shagga', degrees       0.008805
#   closeness     0.325420
#   betweeness    0.005058
#   eigs          0.016243
#   Name: Shagga, dtype: float64),
#  ('Lollys-Stokeworth', degrees       0.008805
#   closeness     0.325020
#   betweeness    0.000012
#   eigs          0.021229
#   Name: Lollys-Stokeworth, dtype: float64),
#  ('Torrhen-Karstark', degrees       0.003774
#   closeness     0.325020
#   betweeness    0.000052
#   eigs          0.013018
#   Name: Torrhen-Karstark, dtype: float64),
#  ('Walder-Rivers', degrees       0.006289
#   closeness     0.324888
#   betweeness    0.000062
#   eigs          0.016284
#   Name: Walder-Rivers, dtype: float64),
#  ('Lemore', degrees       0.008805
#   closeness     0.324755
#   betweeness    0.000002
#   eigs          0.012669
#   Name: Lemore, dtype: float64),
#  ('Yandry', degrees       0.008805
#   closeness     0.324755
#   betweeness    0.000002
#   eigs          0.012669
#   Name: Yandry, dtype: float64),
#  ('Syrio-Forel', degrees       0.005031
#   closeness     0.324357
#   betweeness    0.000010
#   eigs          0.017463
#   Name: Syrio-Forel, dtype: float64),
#  ('Ysilla', degrees       0.007547
#   closeness     0.324225
#   betweeness    0.000000
#   eigs          0.011529
#   Name: Ysilla, dtype: float64),
#  ('Kasporio', degrees       0.003774
#   closeness     0.324093
#   betweeness    0.000000
#   eigs          0.009728
#   Name: Kasporio, dtype: float64),
#  ('Tybero-Istarion', degrees       0.003774
#   closeness     0.324093
#   betweeness    0.000000
#   eigs          0.009728
#   Name: Tybero-Istarion, dtype: float64),
#  ('Timett', degrees       0.005031
#   closeness     0.323961
#   betweeness    0.000004
#   eigs          0.016513
#   Name: Timett, dtype: float64),
#  ('Ballabar', degrees       0.003774
#   closeness     0.323829
#   betweeness    0.002516
#   eigs          0.010065
#   Name: Ballabar, dtype: float64),
#  ('Chella', degrees       0.003774
#   closeness     0.323434
#   betweeness    0.000000
#   eigs          0.015068
#   Name: Chella, dtype: float64),
#  ('Conn', degrees       0.003774
#   closeness     0.323434
#   betweeness    0.002516
#   eigs          0.009383
#   Name: Conn, dtype: float64),
#  ('Chiggen', degrees       0.003774
#   closeness     0.323302
#   betweeness    0.000000
#   eigs          0.012193
#   Name: Chiggen, dtype: float64),
#  ('Yezzan-zo-Qaggaz', degrees       0.006289
#   closeness     0.323302
#   betweeness    0.000006
#   eigs          0.010319
#   Name: Yezzan-zo-Qaggaz, dtype: float64),
#  ('Desmond', degrees       0.002516
#   closeness     0.323171
#   betweeness    0.000000
#   eigs          0.012747
#   Name: Desmond, dtype: float64),
#  ('Symon-Silver-Tongue', degrees       0.003774
#   closeness     0.323171
#   betweeness    0.000000
#   eigs          0.011268
#   Name: Symon-Silver-Tongue, dtype: float64),
#  ('Sweets', degrees       0.003774
#   closeness     0.323039
#   betweeness    0.000000
#   eigs          0.009646
#   Name: Sweets, dtype: float64),
#  ('Jyck', degrees       0.002516
#   closeness     0.322908
#   betweeness    0.000000
#   eigs          0.009122
#   Name: Jyck, dtype: float64),
#  ('Morrec', degrees       0.002516
#   closeness     0.322908
#   betweeness    0.000000
#   eigs          0.009122
#   Name: Morrec, dtype: float64),
#  ('Scar', degrees       0.002516
#   closeness     0.322908
#   betweeness    0.000000
#   eigs          0.009164
#   Name: Scar, dtype: float64),
#  ('Chataya', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Chataya, dtype: float64),
#  ('Galyeon-of-Cuy', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Galyeon-of-Cuy, dtype: float64),
#  ('Gunthor-son-of-Gurn', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Gunthor-son-of-Gurn, dtype: float64),
#  ('Kurleket', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Kurleket, dtype: float64),
#  ('Leo-Lefford', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Leo-Lefford, dtype: float64),
#  ('Mord', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Mord, dtype: float64),
#  ('Morgo', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Morgo, dtype: float64),
#  ('Shrouded-Lord', degrees       0.001258
#   closeness     0.322777
#   betweeness    0.000000
#   eigs          0.008803
#   Name: Shrouded-Lord, dtype: float64),
#  ('Osha', degrees       0.011321
#   closeness     0.321993
#   betweeness    0.000220
#   eigs          0.020249
#   Name: Osha, dtype: float64),
#  ('Dick-Crabb', degrees       0.006289
#   closeness     0.320953
#   betweeness    0.002557
#   eigs          0.017830
#   Name: Dick-Crabb, dtype: float64),
#  ('Howland-Reed', degrees       0.002516
#   closeness     0.320565
#   betweeness    0.000000
#   eigs          0.010995
#   Name: Howland-Reed, dtype: float64),
#  ('Maegor-I-Targaryen', degrees       0.007547
#   closeness     0.320048
#   betweeness    0.002530
#   eigs          0.024894
#   Name: Maegor-I-Targaryen, dtype: float64),
#  ('Tytos-Blackwood', degrees       0.006289
#   closeness     0.319791
#   betweeness    0.000105
#   eigs          0.017031
#   Name: Tytos-Blackwood, dtype: float64),
#  ('Eddison-Tollett', degrees       0.025157
#   closeness     0.319534
#   betweeness    0.003127
#   eigs          0.018740
#   Name: Eddison-Tollett, dtype: float64),
#  ('Nestor-Royce', degrees       0.008805
#   closeness     0.319405
#   betweeness    0.000077
#   eigs          0.025905
#   Name: Nestor-Royce, dtype: float64),
#  ('Robin-Ryger', degrees       0.002516
#   closeness     0.319277
#   betweeness    0.000000
#   eigs          0.014075
#   Name: Robin-Ryger, dtype: float64),
#  ('Cayn', degrees       0.003774
#   closeness     0.319021
#   betweeness    0.000007
#   eigs          0.012301
#   Name: Cayn, dtype: float64),
#  ('Craster', degrees       0.018868
#   closeness     0.318255
#   betweeness    0.003894
#   eigs          0.013387
#   Name: Craster, dtype: float64),
#  ('Aenys-Frey', degrees       0.005031
#   closeness     0.318127
#   betweeness    0.000812
#   eigs          0.011057
#   Name: Aenys-Frey, dtype: float64),
#  ('Alester-Florent', degrees       0.008805
#   closeness     0.318127
#   betweeness    0.000363
#   eigs          0.015098
#   Name: Alester-Florent, dtype: float64),
#  ('Walton', degrees       0.006289
#   closeness     0.318127
#   betweeness    0.002516
#   eigs          0.017162
#   Name: Walton, dtype: float64),
#  ('Gilly', degrees       0.017610
#   closeness     0.317746
#   betweeness    0.001125
#   eigs          0.014639
#   Name: Gilly, dtype: float64),
#  ('Robert-Strong', degrees       0.005031
#   closeness     0.317619
#   betweeness    0.000031
#   eigs          0.014397
#   Name: Robert-Strong, dtype: float64),
#  ('Qhorin-Halfhand', degrees       0.017610
#   closeness     0.317365
#   betweeness    0.002814
#   eigs          0.014000
#   Name: Qhorin-Halfhand, dtype: float64),
#  ('Hobb', degrees       0.013836
#   closeness     0.317112
#   betweeness    0.000087
#   eigs          0.015592
#   Name: Hobb, dtype: float64),
#  ('Grenn', degrees       0.018868
#   closeness     0.316733
#   betweeness    0.000475
#   eigs          0.014405
#   Name: Grenn, dtype: float64),
#  ('Lothar-Frey', degrees       0.013836
#   closeness     0.316607
#   betweeness    0.000278
#   eigs          0.023905
#   Name: Lothar-Frey, dtype: float64),
#  ('Emmon-Frey', degrees       0.010063
#   closeness     0.316229
#   betweeness    0.000464
#   eigs          0.019944
#   Name: Emmon-Frey, dtype: float64),
#  ('Robett-Glover', degrees       0.008805
#   closeness     0.316229
#   betweeness    0.000500
#   eigs          0.011915
#   Name: Robett-Glover, dtype: float64),
#  ('Arnolf-Karstark', degrees       0.006289
#   closeness     0.315852
#   betweeness    0.002620
#   eigs          0.008895
#   Name: Arnolf-Karstark, dtype: float64),
#  ('Chett', degrees       0.008805
#   closeness     0.315727
#   betweeness    0.000096
#   eigs          0.010270
#   Name: Chett, dtype: float64),
#  ('Shagwell', degrees       0.007547
#   closeness     0.315601
#   betweeness    0.000200
#   eigs          0.013527
#   Name: Shagwell, dtype: float64),
#  ('Bryce-Caron', degrees       0.006289
#   closeness     0.315476
#   betweeness    0.005175
#   eigs          0.012067
#   Name: Bryce-Caron, dtype: float64),
#  ('Falyse-Stokeworth', degrees       0.005031
#   closeness     0.315476
#   betweeness    0.000006
#   eigs          0.013240
#   Name: Falyse-Stokeworth, dtype: float64),
#  ('High-Sparrow', degrees       0.010063
#   closeness     0.315476
#   betweeness    0.000038
#   eigs          0.021972
#   Name: High-Sparrow, dtype: float64),
#  ('Dywen', degrees       0.010063
#   closeness     0.315351
#   betweeness    0.000553
#   eigs          0.009906
#   Name: Dywen, dtype: float64),
#  ('Hullen', degrees       0.007547
#   closeness     0.315226
#   betweeness    0.000046
#   eigs          0.019601
#   Name: Hullen, dtype: float64),
#  ('Pypar', degrees       0.020126
#   closeness     0.315226
#   betweeness    0.000234
#   eigs          0.015829
#   Name: Pypar, dtype: float64),
#  ('Weese', degrees       0.010063
#   closeness     0.315226
#   betweeness    0.000107
#   eigs          0.021755
#   Name: Weese, dtype: float64),
#  ('Hodor', degrees       0.013836
#   closeness     0.314976
#   betweeness    0.000213
#   eigs          0.022032
#   Name: Hodor, dtype: float64),
#  ('Lark', degrees       0.007547
#   closeness     0.314976
#   betweeness    0.002589
#   eigs          0.008622
#   Name: Lark, dtype: float64),
#  ('Aerys-I-Targaryen', degrees       0.001258
#   closeness     0.314851
#   betweeness    0.000000
#   eigs          0.006802
#   Name: Aerys-I-Targaryen, dtype: float64),
#  ('Balman-Byrch', degrees       0.003774
#   closeness     0.314727
#   betweeness    0.000000
#   eigs          0.011313
#   Name: Balman-Byrch, dtype: float64),
#  ('Denys-Mallister', degrees       0.011321
#   closeness     0.314727
#   betweeness    0.000013
#   eigs          0.013944
#   Name: Denys-Mallister, dtype: float64),
#  ('Ottyn-Wythers', degrees       0.005031
#   closeness     0.314727
#   betweeness    0.000018
#   eigs          0.008441
#   Name: Ottyn-Wythers, dtype: float64),
#  ('Steffon-Baratheon', degrees       0.002516
#   closeness     0.314727
#   betweeness    0.000000
#   eigs          0.010940
#   Name: Steffon-Baratheon, dtype: float64),
#  ('Genna-Lannister', degrees       0.003774
#   closeness     0.314602
#   betweeness    0.000000
#   eigs          0.014209
#   Name: Genna-Lannister, dtype: float64),
#  ('Roslin-Frey', degrees       0.006289
#   closeness     0.314602
#   betweeness    0.000000
#   eigs          0.017271
#   Name: Roslin-Frey, dtype: float64),
#  ('Salladhor-Saan', degrees       0.006289
#   closeness     0.314478
#   betweeness    0.000010
#   eigs          0.010266
#   Name: Salladhor-Saan, dtype: float64),
#  ('Blue-Bard', degrees       0.006289
#   closeness     0.314353
#   betweeness    0.000908
#   eigs          0.013958
#   Name: Blue-Bard, dtype: float64),
#  ('Dorcas', degrees       0.007547
#   closeness     0.314353
#   betweeness    0.000005
#   eigs          0.016598
#   Name: Dorcas, dtype: float64),
#  ('Othell-Yarwyck', degrees       0.013836
#   closeness     0.314353
#   betweeness    0.000073
#   eigs          0.013671
#   Name: Othell-Yarwyck, dtype: float64),
#  ('Wylis-Manderly', degrees       0.002516
#   closeness     0.314353
#   betweeness    0.000000
#   eigs          0.013511
#   Name: Wylis-Manderly, dtype: float64),
#  ('Thoren-Smallwood', degrees       0.011321
#   closeness     0.314229
#   betweeness    0.002561
#   eigs          0.010129
#   Name: Thoren-Smallwood, dtype: float64),
#  ('Harren-Hoare', degrees       0.003774
#   closeness     0.313981
#   betweeness    0.000077
#   eigs          0.007827
#   Name: Harren-Hoare, dtype: float64),
#  ('Jason-Mallister', degrees       0.003774
#   closeness     0.313981
#   betweeness    0.000065
#   eigs          0.010337
#   Name: Jason-Mallister, dtype: float64),
#  ('Jeyne-Westerling', degrees       0.006289
#   closeness     0.313981
#   betweeness    0.001015
#   eigs          0.015014
#   Name: Jeyne-Westerling, dtype: float64),
#  ('Stevron-Frey', degrees       0.006289
#   closeness     0.313981
#   betweeness    0.000003
#   eigs          0.015712
#   Name: Stevron-Frey, dtype: float64),
#  ('Jocelyn-Swyft', degrees       0.006289
#   closeness     0.313857
#   betweeness    0.000002
#   eigs          0.014795
#   Name: Jocelyn-Swyft, dtype: float64),
#  ('Tallad', degrees       0.007547
#   closeness     0.313857
#   betweeness    0.000845
#   eigs          0.012854
#   Name: Tallad, dtype: float64),
#  ('Torrhen-Stark', degrees       0.002516
#   closeness     0.313857
#   betweeness    0.000000
#   eigs          0.007602
#   Name: Torrhen-Stark, dtype: float64),
#  ('Jalabhar-Xho', degrees       0.006289
#   closeness     0.313733
#   betweeness    0.000807
#   eigs          0.012674
#   Name: Jalabhar-Xho, dtype: float64),
#  ('Aegon-Frey-(son-of-Stevron)', degrees       0.005031
#   closeness     0.313609
#   betweeness    0.000000
#   eigs          0.014688
#   Name: Aegon-Frey-(son-of-Stevron), dtype: float64),
#  ('Desmond-Grell', degrees       0.005031
#   closeness     0.313609
#   betweeness    0.000003
#   eigs          0.014958
#   Name: Desmond-Grell, dtype: float64),
#  ('Moon-Boy', degrees       0.005031
#   closeness     0.313486
#   betweeness    0.000009
#   eigs          0.014160
#   Name: Moon-Boy, dtype: float64),
#  ('Walder-Frey-(son-of-Merrett)', degrees       0.010063
#   closeness     0.313486
#   betweeness    0.000137
#   eigs          0.017586
#   Name: Walder-Frey-(son-of-Merrett), dtype: float64),
#  ('Wendel-Manderly', degrees       0.008805
#   closeness     0.313486
#   betweeness    0.002580
#   eigs          0.014753
#   Name: Wendel-Manderly, dtype: float64),
#  ('Daryn-Hornwood', degrees       0.002516
#   closeness     0.313362
#   betweeness    0.000000
#   eigs          0.007162
#   Name: Daryn-Hornwood, dtype: float64),
#  ('Maege-Mormont', degrees       0.006289
#   closeness     0.313362
#   betweeness    0.000004
#   eigs          0.015337
#   Name: Maege-Mormont, dtype: float64),
#  ('Jacks', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Jacks, dtype: float64),
#  ('Joss', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Joss, dtype: float64),
#  ('Justin-Massey', degrees       0.006289
#   closeness     0.313239
#   betweeness    0.000048
#   eigs          0.008232
#   Name: Justin-Massey, dtype: float64),
#  ('Maron-Greyjoy', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Maron-Greyjoy, dtype: float64),
#  ('Porther', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Porther, dtype: float64),
#  ('Senelle', degrees       0.002516
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.011465
#   Name: Senelle, dtype: float64),
#  ('Tobho-Mott', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Tobho-Mott, dtype: float64),
#  ('Tregar', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Tregar, dtype: float64),
#  ('Varly', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Varly, dtype: float64),
#  ('Wylla', degrees       0.001258
#   closeness     0.313239
#   betweeness    0.000000
#   eigs          0.006707
#   Name: Wylla, dtype: float64),
#  ('Ygritte', degrees       0.016352
#   closeness     0.313239
#   betweeness    0.002655
#   eigs          0.011018
#   Name: Ygritte, dtype: float64),
#  ('Euron-Greyjoy', degrees       0.016352
#   closeness     0.313115
#   betweeness    0.008005
#   eigs          0.006744
#   Name: Euron-Greyjoy, dtype: float64),
#  ('Osfryd-Kettleblack', degrees       0.003774
#   closeness     0.313115
#   betweeness    0.000000
#   eigs          0.011720
#   Name: Osfryd-Kettleblack, dtype: float64),
#  ('Aeron-Greyjoy', degrees       0.018868
#   closeness     0.312992
#   betweeness    0.012935
#   eigs          0.007115
#   Name: Aeron-Greyjoy, dtype: float64),
#  ('Alysane-Mormont', degrees       0.003774
#   closeness     0.312992
#   betweeness    0.000000
#   eigs          0.007465
#   Name: Alysane-Mormont, dtype: float64),
#  ('Clayton-Suggs', degrees       0.003774
#   closeness     0.312992
#   betweeness    0.000000
#   eigs          0.007738
#   Name: Clayton-Suggs, dtype: float64),
#  ('Lyle-Crakehall', degrees       0.006289
#   closeness     0.312992
#   betweeness    0.000009
#   eigs          0.015552
#   Name: Lyle-Crakehall, dtype: float64),
#  ('Rattleshirt', degrees       0.013836
#   closeness     0.312992
#   betweeness    0.000083
#   eigs          0.010949
#   Name: Rattleshirt, dtype: float64),
#  ('Unella', degrees       0.005031
#   closeness     0.312992
#   betweeness    0.000003
#   eigs          0.009642
#   Name: Unella, dtype: float64),
#  ('Maggy', degrees       0.002516
#   closeness     0.312869
#   betweeness    0.000000
#   eigs          0.008827
#   Name: Maggy, dtype: float64),
#  ('Moelle', degrees       0.003774
#   closeness     0.312869
#   betweeness    0.000000
#   eigs          0.008899
#   Name: Moelle, dtype: float64),
#  ('Raynard', degrees       0.002516
#   closeness     0.312869
#   betweeness    0.002516
#   eigs          0.008260
#   Name: Raynard, dtype: float64),
#  ('Scolera', degrees       0.003774
#   closeness     0.312869
#   betweeness    0.000000
#   eigs          0.008899
#   Name: Scolera, dtype: float64),
#  ('Colemon', degrees       0.007547
#   closeness     0.312746
#   betweeness    0.000115
#   eigs          0.014396
#   Name: Colemon, dtype: float64),
#  ('Dacey-Mormont', degrees       0.003774
#   closeness     0.312746
#   betweeness    0.000000
#   eigs          0.012752
#   Name: Dacey-Mormont, dtype: float64),
#  ('Raynald-Westerling', degrees       0.003774
#   closeness     0.312746
#   betweeness    0.000032
#   eigs          0.012443
#   Name: Raynald-Westerling, dtype: float64),
#  ('Utherydes-Wayn', degrees       0.003774
#   closeness     0.312746
#   betweeness    0.000000
#   eigs          0.012739
#   Name: Utherydes-Wayn, dtype: float64),
#  ('Garth-Tyrell', degrees       0.001258
#   closeness     0.312623
#   betweeness    0.000000
#   eigs          0.008250
#   Name: Garth-Tyrell, dtype: float64),
#  ('Mariya-Darry', degrees       0.002516
#   closeness     0.312623
#   betweeness    0.000000
#   eigs          0.010270
#   Name: Mariya-Darry, dtype: float64),
#  ('Mark-Mullendore', degrees       0.001258
#   closeness     0.312623
#   betweeness    0.000000
#   eigs          0.008250
#   Name: Mark-Mullendore, dtype: float64),
#  ('Karyl-Vance', degrees       0.005031
#   closeness     0.312500
#   betweeness    0.000021
#   eigs          0.011640
#   Name: Karyl-Vance, dtype: float64),
#  ('Zollo', degrees       5.031447e-03
#   closeness     3.125000e-01
#   betweeness    6.336834e-07
#   eigs          1.013085e-02
#   Name: Zollo, dtype: float64),
#  ('Edwyn-Frey', degrees       0.005031
#   closeness     0.312377
#   betweeness    0.000001
#   eigs          0.011649
#   Name: Edwyn-Frey, dtype: float64),
#  ('Halder', degrees       0.010063
#   closeness     0.312255
#   betweeness    0.000044
#   eigs          0.009800
#   Name: Halder, dtype: float64),
#  ('Biter', degrees       0.006289
#   closeness     0.312132
#   betweeness    0.000094
#   eigs          0.012854
#   Name: Biter, dtype: float64),
#  ('Ronnet-Connington', degrees       0.002516
#   closeness     0.312132
#   betweeness    0.000000
#   eigs          0.010498
#   Name: Ronnet-Connington, dtype: float64),
#  ('Beth-Cassel', degrees       0.003774
#   closeness     0.312009
#   betweeness    0.000000
#   eigs          0.011151
#   Name: Beth-Cassel, dtype: float64),
#  ('Jaremy-Rykker', degrees       0.006289
#   closeness     0.312009
#   betweeness    0.002519
#   eigs          0.008864
#   Name: Jaremy-Rykker, dtype: float64),
#  ('Rast', degrees       0.007547
#   closeness     0.312009
#   betweeness    0.000023
#   eigs          0.009095
#   Name: Rast, dtype: float64),
#  ('Tormund', degrees       0.018868
#   closeness     0.312009
#   betweeness    0.005150
#   eigs          0.011309
#   Name: Tormund, dtype: float64),
#  ('Amerei-Frey', degrees       0.003774
#   closeness     0.311887
#   betweeness    0.000002
#   eigs          0.010507
#   Name: Amerei-Frey, dtype: float64),
#  ('Daven-Lannister', degrees       0.003774
#   closeness     0.311887
#   betweeness    0.000000
#   eigs          0.010718
#   Name: Daven-Lannister, dtype: float64),
#  ('Satin', degrees       0.016352
#   closeness     0.311887
#   betweeness    0.002941
#   eigs          0.009988
#   Name: Satin, dtype: float64),
#  ('Shadrich', degrees       0.002516
#   closeness     0.311765
#   betweeness    0.000133
#   eigs          0.008078
#   Name: Shadrich, dtype: float64),
#  ('Clement-Piper', degrees       0.002516
#   closeness     0.311642
#   betweeness    0.000000
#   eigs          0.008327
#   Name: Clement-Piper, dtype: float64),
#  ('Colen-of-Greenpools', degrees       0.002516
#   closeness     0.311642
#   betweeness    0.000000
# ...
#   Name: Wulfe, dtype: float64),
#  ('Ogo', degrees       0.003774
#   closeness     0.249373
#   betweeness    0.002516
#   eigs          0.000537
#   Name: Ogo, dtype: float64),
#  ('Jommo', degrees       0.002516
#   closeness     0.249294
#   betweeness    0.000000
#   eigs          0.000536
#   Name: Jommo, dtype: float64),
#  ('Rhaego', degrees       0.001258
#   closeness     0.249138
#   betweeness    0.000000
#   eigs          0.000517
#   Name: Rhaego, dtype: float64),
#  ('Dancy', degrees       0.001258
#   closeness     0.247895
#   betweeness    0.000000
#   eigs          0.000689
#   Name: Dancy, dtype: float64),
#  ('Sharna', degrees       0.005031
#   closeness     0.247125
#   betweeness    0.000002
#   eigs          0.002409
#   Name: Sharna, dtype: float64),
#  ('Jeyne-Farman', degrees       0.001258
#   closeness     0.246359
#   betweeness    0.000000
#   eigs          0.000577
#   Name: Jeyne-Farman, dtype: float64),
#  ('Husband', degrees       0.002516
#   closeness     0.246206
#   betweeness    0.000000
#   eigs          0.001473
#   Name: Husband, dtype: float64),
#  ('Jack-Be-Lucky', degrees       0.001258
#   closeness     0.246130
#   betweeness    0.000000
#   eigs          0.000929
#   Name: Jack-Be-Lucky, dtype: float64),
#  ('Lanna-(Happy-Port)', degrees       0.001258
#   closeness     0.246130
#   betweeness    0.000000
#   eigs          0.000504
#   Name: Lanna-(Happy-Port), dtype: float64),
#  ('Dolf', degrees       0.001258
#   closeness     0.245598
#   betweeness    0.000000
#   eigs          0.000568
#   Name: Dolf, dtype: float64),
#  ('Ulf-son-of-Umar', degrees       0.001258
#   closeness     0.245598
#   betweeness    0.000000
#   eigs          0.000568
#   Name: Ulf-son-of-Umar, dtype: float64),
#  ('Frenken', degrees       0.001258
#   closeness     0.244691
#   betweeness    0.000000
#   eigs          0.000352
#   Name: Frenken, dtype: float64),
#  ('Coratt', degrees       0.001258
#   closeness     0.244465
#   betweeness    0.000000
#   eigs          0.000328
#   Name: Coratt, dtype: float64),
#  ('Eustace-Brune', degrees       0.001258
#   closeness     0.243045
#   betweeness    0.000000
#   eigs          0.000624
#   Name: Eustace-Brune, dtype: float64),
#  ('Jaehaerys-I-Targaryen', degrees       0.001258
#   closeness     0.242526
#   betweeness    0.000000
#   eigs          0.000871
#   Name: Jaehaerys-I-Targaryen, dtype: float64),
#  ('Watt', degrees       0.001258
#   closeness     0.242230
#   betweeness    0.000000
#   eigs          0.000656
#   Name: Watt, dtype: float64),
#  ('Byam-Flint', degrees       0.001258
#   closeness     0.241495
#   betweeness    0.000000
#   eigs          0.000469
#   Name: Byam-Flint, dtype: float64),
#  ('Nage', degrees       0.001258
#   closeness     0.241421
#   betweeness    0.000000
#   eigs          0.000601
#   Name: Nage, dtype: float64),
#  ('Ragwyle', degrees       0.001258
#   closeness     0.240982
#   betweeness    0.000000
#   eigs          0.000490
#   Name: Ragwyle, dtype: float64),
#  ('Arthor-Karstark', degrees       0.001258
#   closeness     0.240109
#   betweeness    0.000000
#   eigs          0.000311
#   Name: Arthor-Karstark, dtype: float64),
#  ('Eldon-Estermont', degrees       0.002516
#   closeness     0.240036
#   betweeness    0.002516
#   eigs          0.000423
#   Name: Eldon-Estermont, dtype: float64),
#  ('Lambert-Turnberry', degrees       0.003774
#   closeness     0.239891
#   betweeness    0.000001
#   eigs          0.001382
#   Name: Lambert-Turnberry, dtype: float64),
#  ('Softfoot', degrees       0.001258
#   closeness     0.239602
#   betweeness    0.000000
#   eigs          0.000302
#   Name: Softfoot, dtype: float64),
#  ('Mallador-Locke', degrees       0.001258
#   closeness     0.239170
#   betweeness    0.000000
#   eigs          0.000355
#   Name: Mallador-Locke, dtype: float64),
#  ('Shadd', degrees       0.001258
#   closeness     0.238739
#   betweeness    0.000000
#   eigs          0.000516
#   Name: Shadd, dtype: float64),
#  ('Bael-the-Bard', degrees       0.001258
#   closeness     0.238595
#   betweeness    0.000000
#   eigs          0.000386
#   Name: Bael-the-Bard, dtype: float64),
#  ('Sawane-Botley', degrees       0.001258
#   closeness     0.238524
#   betweeness    0.000000
#   eigs          0.000236
#   Name: Sawane-Botley, dtype: float64),
#  ('Emmond', degrees       0.001258
#   closeness     0.238452
#   betweeness    0.000000
#   eigs          0.000249
#   Name: Emmond, dtype: float64),
#  ('Gormond-Goodbrother', degrees       0.001258
#   closeness     0.238452
#   betweeness    0.000000
#   eigs          0.000249
#   Name: Gormond-Goodbrother, dtype: float64),
#  ('Greydon-Goodbrother', degrees       0.001258
#   closeness     0.238452
#   betweeness    0.000000
#   eigs          0.000249
#   Name: Greydon-Goodbrother, dtype: float64),
#  ('Rus', degrees       0.001258
#   closeness     0.238452
#   betweeness    0.000000
#   eigs          0.000249
#   Name: Rus, dtype: float64),
#  ('Torbert', degrees       0.001258
#   closeness     0.238381
#   betweeness    0.000000
#   eigs          0.000289
#   Name: Torbert, dtype: float64),
#  ('Arron', degrees       0.003774
#   closeness     0.238238
#   betweeness    0.000000
#   eigs          0.000622
#   Name: Arron, dtype: float64),
#  ('Emrick', degrees       0.003774
#   closeness     0.238238
#   betweeness    0.000000
#   eigs          0.000622
#   Name: Emrick, dtype: float64),
#  ('Dryn', degrees       0.001258
#   closeness     0.237882
#   betweeness    0.000000
#   eigs          0.000396
#   Name: Dryn, dtype: float64),
#  ('Jafer-Flowers', degrees       0.001258
#   closeness     0.237882
#   betweeness    0.000000
#   eigs          0.000310
#   Name: Jafer-Flowers, dtype: float64),
#  ('Munda', degrees       0.001258
#   closeness     0.237882
#   betweeness    0.000000
#   eigs          0.000396
#   Name: Munda, dtype: float64),
#  ('Rugen', degrees       0.001258
#   closeness     0.237668
#   betweeness    0.000000
#   eigs          0.000277
#   Name: Rugen, dtype: float64),
#  ('Bump', degrees       0.001258
#   closeness     0.236889
#   betweeness    0.000000
#   eigs          0.000251
#   Name: Bump, dtype: float64),
#  ('Haggon', degrees       0.001258
#   closeness     0.236889
#   betweeness    0.000000
#   eigs          0.000251
#   Name: Haggon, dtype: float64),
#  ('Thistle', degrees       0.001258
#   closeness     0.236889
#   betweeness    0.000000
#   eigs          0.000251
#   Name: Thistle, dtype: float64),
#  ('Tion-Frey', degrees       0.001258
#   closeness     0.236678
#   betweeness    0.000000
#   eigs          0.000310
#   Name: Tion-Frey, dtype: float64),
#  ('Ardrian-Celtigar', degrees       0.001258
#   closeness     0.236607
#   betweeness    0.000000
#   eigs          0.000277
#   Name: Ardrian-Celtigar, dtype: float64),
#  ('Raymun-Redbeard', degrees       0.001258
#   closeness     0.235835
#   betweeness    0.000000
#   eigs          0.000177
#   Name: Raymun-Redbeard, dtype: float64),
#  ('Torghen-Flint', degrees       0.001258
#   closeness     0.235835
#   betweeness    0.000000
#   eigs          0.000177
#   Name: Torghen-Flint, dtype: float64),
#  ('Horton-Redfort', degrees       0.005031
#   closeness     0.235556
#   betweeness    0.000002
#   eigs          0.001115
#   Name: Horton-Redfort, dtype: float64),
#  ('Mebble', degrees       0.001258
#   closeness     0.234375
#   betweeness    0.000000
#   eigs          0.000490
#   Name: Mebble, dtype: float64),
#  ('Gynir', degrees       0.002516
#   closeness     0.232728
#   betweeness    0.000081
#   eigs          0.000239
#   Name: Gynir, dtype: float64),
#  ('Hobber-Redwyne', degrees       0.001258
#   closeness     0.232592
#   betweeness    0.000000
#   eigs          0.000263
#   Name: Hobber-Redwyne, dtype: float64),
#  ('Jonquil', degrees       0.001258
#   closeness     0.232320
#   betweeness    0.000000
#   eigs          0.000252
#   Name: Jonquil, dtype: float64),
#  ('Belaquo', degrees       0.005031
#   closeness     0.231374
#   betweeness    0.000013
#   eigs          0.000766
#   Name: Belaquo, dtype: float64),
#  ('Harl', degrees       0.001258
#   closeness     0.230435
#   betweeness    0.000000
#   eigs          0.000145
#   Name: Harl, dtype: float64),
#  ('Luton', degrees       0.001258
#   closeness     0.230168
#   betweeness    0.000000
#   eigs          0.000198
#   Name: Luton, dtype: float64),
#  ('Prendahl-na-Ghezn', degrees       0.002516
#   closeness     0.230168
#   betweeness    0.000000
#   eigs          0.000406
#   Name: Prendahl-na-Ghezn, dtype: float64),
#  ('Sallor', degrees       0.002516
#   closeness     0.230168
#   betweeness    0.000000
#   eigs          0.000406
#   Name: Sallor, dtype: float64),
#  ('Caggo', degrees       0.006289
#   closeness     0.230101
#   betweeness    0.002516
#   eigs          0.000809
#   Name: Caggo, dtype: float64),
#  ('Archibald-Yronwood', degrees       0.005031
#   closeness     0.229902
#   betweeness    0.000002
#   eigs          0.000804
#   Name: Archibald-Yronwood, dtype: float64),
#  ('Kedry', degrees       0.002516
#   closeness     0.229570
#   betweeness    0.000000
#   eigs          0.000458
#   Name: Kedry, dtype: float64),
#  ('Old-Bill-Bone', degrees       0.001258
#   closeness     0.229503
#   betweeness    0.000000
#   eigs          0.000358
#   Name: Old-Bill-Bone, dtype: float64),
#  ('Cedra', degrees       0.002516
#   closeness     0.228186
#   betweeness    0.000000
#   eigs          0.000599
#   Name: Cedra, dtype: float64),
#  ('Ricasso', degrees       0.002516
#   closeness     0.228186
#   betweeness    0.002516
#   eigs          0.000431
#   Name: Ricasso, dtype: float64),
#  ('Mellei', degrees       0.002516
#   closeness     0.228121
#   betweeness    0.000000
#   eigs          0.000446
#   Name: Mellei, dtype: float64),
#  ('Morra', degrees       0.002516
#   closeness     0.228121
#   betweeness    0.000000
#   eigs          0.000446
#   Name: Morra, dtype: float64),
#  ('Franklyn-Fowler', degrees       0.001258
#   closeness     0.228055
#   betweeness    0.000000
#   eigs          0.000430
#   Name: Franklyn-Fowler, dtype: float64),
#  ('Timoth', degrees       0.001258
#   closeness     0.228055
#   betweeness    0.000000
#   eigs          0.000430
#   Name: Timoth, dtype: float64),
#  ('Goghor-the-Giant', degrees       0.005031
#   closeness     0.227924
#   betweeness    0.000001
#   eigs          0.000622
#   Name: Goghor-the-Giant, dtype: float64),
#  ('Marghaz-zo-Loraq', degrees       0.001258
#   closeness     0.227663
#   betweeness    0.000000
#   eigs          0.000357
#   Name: Marghaz-zo-Loraq, dtype: float64),
#  ('Will-(prologue)', degrees       0.002516
#   closeness     0.223692
#   betweeness    0.000000
#   eigs          0.000125
#   Name: Will-(prologue), dtype: float64),
#  ('Grazdan-mo-Eraz', degrees       0.001258
#   closeness     0.219674
#   betweeness    0.000000
#   eigs          0.000125
#   Name: Grazdan-mo-Eraz, dtype: float64),
#  ('Jared-Frey', degrees       0.003774
#   closeness     0.219613
#   betweeness    0.000006
#   eigs          0.000182
#   Name: Jared-Frey, dtype: float64),
#  ('Dick-Straw', degrees       0.002516
#   closeness     0.219069
#   betweeness    0.002516
#   eigs          0.000111
#   Name: Dick-Straw, dtype: float64),
#  ('Denzo-Dhan', degrees       0.001258
#   closeness     0.218767
#   betweeness    0.000000
#   eigs          0.000103
#   Name: Denzo-Dhan, dtype: float64),
#  ('Camarron', degrees       0.001258
#   closeness     0.217749
#   betweeness    0.000000
#   eigs          0.000096
#   Name: Camarron, dtype: float64),
#  ('Draqaz', degrees       0.001258
#   closeness     0.217332
#   betweeness    0.000000
#   eigs          0.000081
#   Name: Draqaz, dtype: float64),
#  ('Smiling-Knight', degrees       0.002516
#   closeness     0.217332
#   betweeness    0.002516
#   eigs          0.000189
#   Name: Smiling-Knight, dtype: float64),
#  ('Elys-Waynwood', degrees       0.001258
#   closeness     0.217035
#   betweeness    0.000000
#   eigs          0.000098
#   Name: Elys-Waynwood, dtype: float64),
#  ('Sarella-Sand', degrees       0.001258
#   closeness     0.216268
#   betweeness    0.000000
#   eigs          0.000181
#   Name: Sarella-Sand, dtype: float64),
#  ('Shortear', degrees       0.001258
#   closeness     0.216268
#   betweeness    0.000000
#   eigs          0.000136
#   Name: Shortear, dtype: float64),
#  ('Pate-(novice)', degrees       0.008805
#   closeness     0.215097
#   betweeness    0.010042
#   eigs          0.000175
#   Name: Pate-(novice), dtype: float64),
#  ('Armen', degrees       0.007547
#   closeness     0.214981
#   betweeness    0.000017
#   eigs          0.000236
#   Name: Armen, dtype: float64),
#  ('Mollander', degrees       0.005031
#   closeness     0.214865
#   betweeness    0.000004
#   eigs          0.000123
#   Name: Mollander, dtype: float64),
#  ('Roone', degrees       5.031447e-03
#   closeness     2.146328e-01
#   betweeness    7.921043e-07
#   eigs          1.739919e-04
#   Name: Roone, dtype: float64),
#  ('Gariss', degrees       0.002516
#   closeness     0.212170
#   betweeness    0.002516
#   eigs          0.000058
#   Name: Gariss, dtype: float64),
#  ('Sigfryd-Harlaw', degrees       0.002516
#   closeness     0.212170
#   betweeness    0.000000
#   eigs          0.000072
#   Name: Sigfryd-Harlaw, dtype: float64),
#  ('Gelmarr', degrees       0.001258
#   closeness     0.212057
#   betweeness    0.000000
#   eigs          0.000058
#   Name: Gelmarr, dtype: float64),
#  ('Gerald-Gower', degrees       0.001258
#   closeness     0.208552
#   betweeness    0.000000
#   eigs          0.000074
#   Name: Gerald-Gower, dtype: float64),
#  ('Lucas-Codd', degrees       0.002516
#   closeness     0.207301
#   betweeness    0.002516
#   eigs          0.000037
#   Name: Lucas-Codd, dtype: float64),
#  ('Cromm', degrees       0.002516
#   closeness     0.207247
#   betweeness    0.000000
#   eigs          0.000071
#   Name: Cromm, dtype: float64),
#  ('Black-Balaq', degrees       0.001258
#   closeness     0.206547
#   betweeness    0.000000
#   eigs          0.000072
#   Name: Black-Balaq, dtype: float64),
#  ('Malaquo-Maegyr', degrees       0.001258
#   closeness     0.206226
#   betweeness    0.000000
#   eigs          0.000041
#   Name: Malaquo-Maegyr, dtype: float64),
#  ('Jonothor-Darry', degrees       0.002516
#   closeness     0.203898
#   betweeness    0.000000
#   eigs          0.000077
#   Name: Jonothor-Darry, dtype: float64),
#  ('Kurz', degrees       0.001258
#   closeness     0.203325
#   betweeness    0.000000
#   eigs          0.000049
#   Name: Kurz, dtype: float64),
#  ('Tarber', degrees       0.001258
#   closeness     0.203325
#   betweeness    0.000000
#   eigs          0.000049
#   Name: Tarber, dtype: float64),
#  ('Gerold-Grafton', degrees       0.001258
#   closeness     0.202961
#   betweeness    0.000000
#   eigs          0.000053
#   Name: Gerold-Grafton, dtype: float64),
#  ('Fogo', degrees       0.001258
#   closeness     0.199648
#   betweeness    0.000000
#   eigs          0.000019
#   Name: Fogo, dtype: float64),
#  ('Steffon-Varner', degrees       0.001258
#   closeness     0.193619
#   betweeness    0.000000
#   eigs          0.000015
#   Name: Steffon-Varner, dtype: float64),
#  ('Lucifer-Long', degrees       0.001258
#   closeness     0.187103
#   betweeness    0.000000
#   eigs          0.000028
#   Name: Lucifer-Long, dtype: float64),
#  ('Manfrey-Martell', degrees       0.001258
#   closeness     0.185835
#   betweeness    0.000000
#   eigs          0.000015
#   Name: Manfrey-Martell, dtype: float64),
#  ('Hugh-Hungerford', degrees       0.001258
#   closeness     0.179742
#   betweeness    0.000000
#   eigs          0.000004
#   Name: Hugh-Hungerford, dtype: float64),
#  ('Simon-Toyne', degrees       0.001258
#   closeness     0.178571
#   betweeness    0.000000
#   eigs          0.000007
#   Name: Simon-Toyne, dtype: float64),
#  ('Walgrave', degrees       0.002516
#   closeness     0.177139
#   betweeness    0.002516
#   eigs          0.000006
#   Name: Walgrave, dtype: float64),
#  ('Quill', degrees       0.001258
#   closeness     0.177060
#   betweeness    0.000000
#   eigs          0.000006
#   Name: Quill, dtype: float64),
#  ('Rosey', degrees       0.001258
#   closeness     0.177060
#   betweeness    0.000000
#   eigs          0.000006
#   Name: Rosey, dtype: float64),
#  ('Murch', degrees       0.001258
#   closeness     0.175072
#   betweeness    0.000000
#   eigs          0.000002
#   Name: Murch, dtype: float64),
#  ('Torwold-Browntooth', degrees       0.001258
#   closeness     0.171743
#   betweeness    0.000000
#   eigs          0.000001
#   Name: Torwold-Browntooth, dtype: float64),
#  ('Gormon-Tyrell', degrees       1.257862e-03
#   closeness     1.505112e-01
#   betweeness    0.000000e+00
#   eigs          2.148365e-07
#   Name: Gormon-Tyrell, dtype: float64)]

# %% [markdown]
# ## Drawing the Graph
#
# To visualize all of these relationships, draw a graph of the network.

# %%
nx.draw(G, alpha=.6, with_labels=True )

# %% [markdown]
# ## Subsetting the Graph
#
# As you can see, the above graph is undoubtedly noisy, making it difficult to discern any useful patterns. As such, reset the graph and only add edges whose weight is 75 or greater. From there, redraw the graph. To further help with the display, try using `nx.spring_layout(G, random_state=8)` for the position. To jazz it up, try and recolor those nodes which you identified as bridge or bottleneck nodes to communication.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# In this lab, we looked at different centrality measures of the graph data for the ASIOF dataset. We also compared these measures to see how they correlate with each other. We also saw in practice, the difference between taking the weighted centrality measures and how it may effect the results.
